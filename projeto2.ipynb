# %% [markdown]
# # Projeto Prático 2
#
# 1) Gere dados a partir de uma distribuição de Poisson. Varie a taxas λ no intervalo [1,10] e mostre o gráfico da média em função da variância.
# 2) Considere os dados da Iris. Calcule a média, variância e IQR para cada atributo.
# 3) Obtenha o boxplot de todas as variáveis da flor Iris, para cada espécie.
# 4) Para a função log(), investigue como as correlações de Pearson e Spearman variam de acordo com o intervalo dos dados.
# 5) Considere o código que mostra como a correlação de Pearson muda com a inclusão de ruídos (ver Python: Análise Exploratória de Dados). Modifique a função para Y=0.5∗X+Y=0.5∗X+ruído. Varie o ruído e calcule os coeficientes de Pearson e Spearman, mostrando os respectivos scatterplots com os valores dos coeficientes (como feito no exemplo).
# 6) Considere os dados abaixo, chamado quarteto de Ascomb. Calcule a média, variância, correlação de Pearson e Spearman entre as variáveis x e y. O que você pode dizer sobre esses dados?

# %%
import matplotlib.pyplot as plt
import numpy as np
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]
datasets = {
 'I': (x, y1),
 'II': (x, y2),
 'III': (x, y3),
 'IV': (x4, y4)
}

fig, axs = plt.subplots(2, 2, sharex=True, sharey=True, figsize=(10
, 5),
 gridspec_kw={'wspace': 0.08, 'hspace': 0.08
})
for ax, (label, (x, y)) in zip(axs.flat, datasets.items()):
 ax.text(0.1, 0.9, label, fontsize=20, transform=ax.transAxes, va='top')
 ax.tick_params(direction='in', top=True, right=True)
 ax.plot(x, y, 'o')
plt.show()

# %% [markdown]
# **Imports**

# %%
import statistics 
import matplotlib.pyplot as plt 
from scipy.stats import poisson 
from scipy.stats import iqr
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# **1 - Gere dados a partir de uma distribuição de Poisson. Varie a taxas λ no intervalo [1,10]
# e mostre o gráfico da média em função da variância**

# %%
# For para a variancia de lambda e ja fazer o grafico com media e variancia
for i in range(1,11):
  z=poisson.rvs(mu=i, size=1000)
  plt.scatter(statistics.mean(z),statistics.pvariance(z))
# titulo e nome dos eixos
plt.title('gráfico da média em função da variância')
plt.xlabel('Media')
plt.ylabel('Variancia')
# Out:
# Text(0, 0.5, 'Variancia')

# %% [markdown]
# **2 - Considere os dados da Iris. Calcule a média, variância e IQR para cada atributo.**

# %%
# Lendos os dados
data = pd.read_csv('iris.csv', header=(0))
data = data.drop(data.columns[[-1]], axis=1)
data.head()
data_trans=data.T
W = np.array(data_trans[data_trans.columns[0:data_trans.shape[1]-1]], dtype= float)
print ('Do comprimento da sépala:\n','Média =',statistics.mean(W[0]),'\n Variância =', statistics.pvariance(W[0]),'\n IQC =',iqr(W[0]))
 
print ('\nDa largura da sépala:\n','Média =', statistics.mean(W[1]),'\n Variância =', statistics.pvariance(W[1]),'\n IQC =', iqr(W[1]))
print ('\nDo comprimento da pétala:\n','Média =', statistics.mean(W[2]),'\n Variância =', statistics.pvariance(W[2]),'\n IQC =',iqr(W[2]))
 
print ('\nDo largura da pétala:\n','Média =', statistics.mean(W[3]),'\n Variância =', statistics.pvariance(W[3]),'\n IQC =', iqr(W[3]))
# Out:
# Do comprimento da sépala:
#  Média = 5.842953020134228
#  Variância = 0.6856718165848386
#  IQC = 1.3000000000000007
#
# Da largura da sépala:
#  Média = 3.0543624161073826
#  Variância = 0.18798432503040402
#  IQC = 0.5
#
# Do comprimento da pétala:
#  Média = 3.7496644295302013
#  Variância = 3.1010233773253457
#  IQC = 3.4999999999999996
#
# Do largura da pétala:
#  Média = 1.1946308724832215
#  Variância = 0.5799711724697085
#  IQC = 1.5

# %% [markdown]
# **3 - Obtenha o boxplot de todas as variáveis da flor Iris, para cada espécie.**

# %%
# CSV file
data = pd.read_csv('iris.csv', header=(0))

# Definindo o tamanho do gáfico
plt.figure(figsize=(8, 8))

# Mostra o boxplot com a variável largura da sepala
sns.boxplot(x="species", y="sepal_length", data=data) 
plt.xlabel('Espécie', fontsize=18)
plt.ylabel('Comprimento da sépala', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show(True)

# Mostra o boxplot com a variável comprimento da sepala
sns.boxplot(x="species", y="sepal_width", data=data)
plt.xlabel('Espécie', fontsize=18)
plt.ylabel('Largura da sépala', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show(True)

# Mostra o boxplot com a variável largura da petala
sns.boxplot(x="species", y="petal_length", data=data) 
plt.xlabel('Espécie', fontsize=18)
plt.ylabel('Comprimento da pétala', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show(True)

# Mostra o boxplot com a variável comprimento da petala
sns.boxplot(x="species", y="petal_width", data=data) 
plt.xlabel('Espécie', fontsize=18)
plt.ylabel('Largura da pétala', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show(True)

# %% [markdown]
# **4 - Para a função log(), investigue como as correlações de Pearson e Spearman variam de
# acordo com o intervalo dos dados.**

# %%
import numpy as np
import matplotlib.pyplot as plt 
from scipy.stats import pearsonr, spearmanr 

# Gerando N pontos de 1 a 50000
N = 100
x = np.linspace(1, 50000, N) 
z = np.log(x)

plt.plot(x, z) 
plt.xlabel("x",fontsize = 20) 
plt.ylabel("Log(X)", fontsize = 20) 
corr, p_value = pearsonr(x, z)
corrs, p_values = spearmanr(x, z)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
string = 'Pearson corr. = '+ str(corr)
plt.text(20000,3, string, fontsize=15)
string = 'Spearman corr. = '+ str(corrs)
plt.text(20000,1, string, fontsize=15)
plt.show()

# %%
# Gerando N pontos de 1 a 500000
N = 100
x = np.linspace(1, 500000, N) 
z = np.log(x)

plt.plot(x, z) 
plt.xlabel("x",fontsize = 20) 
plt.ylabel("Log(X)", fontsize = 20) 
corr, p_value = pearsonr(x, z)
corrs, p_values = spearmanr(x, z)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
string = 'Pearson corr. = '+ str(corr)
plt.text(20000,3, string, fontsize=15)
string = 'Spearman corr. = '+ str(corrs)
plt.text(20000,1, string, fontsize=15)
plt.show()

# %%
# Gerando N pontos de 1 a 5000000
N = 100
x = np.linspace(1, 5000000, N) 
z = np.log(x)

plt.plot(x, z) 
plt.xlabel("x",fontsize = 20) 
plt.ylabel("Log(X)", fontsize = 20) 
corr, p_value = pearsonr(x, z)
corrs, p_values = spearmanr(x, z)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
string = 'Pearson corr. = '+ str(corr)
plt.text(20000,3, string, fontsize=15)
string = 'Spearman corr. = '+ str(corrs)
plt.text(20000,1, string, fontsize=15)
plt.show()

# %%
# Gerando N pontos de 1 a 500000000
N = 100
x = np.linspace(1, 500000000, N) 
z = np.log(x)

plt.plot(x, z) 
plt.xlabel("x",fontsize = 20) 
plt.ylabel("Log(X)", fontsize = 20) 
corr, p_value = pearsonr(x, z)
corrs, p_values = spearmanr(x, z)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
string = 'Pearson corr. = '+ str(corr)
plt.text(20000,3, string, fontsize=15)
string = 'Spearman corr. = '+ str(corrs)
plt.text(20000,1, string, fontsize=15)
plt.show()

# %% [markdown]
# Primeiramente, foram gerados N pontos entre 1 e 50000 (sendo N=100). Nos outros exemplos, aumentou-se os intervalos, gerando pontos de 1 a 500000, 1 a 5000000 e 1 a 500000000. A medida que os intervalos vão aumentando, percebe-se que   o valor da correlação de Pearson diminui, enquanto o valor da correlação de Spearman continua o mesmo.

# %% [markdown]
# **5 - Considere o código que mostra como a correlação de Pearson muda com a inclusão
# de ruídos (ver Python: Análise Exploratória de Dados). Modifique a função
# para Y=0.5*X+ruído. Varie o ruído e calcule os coeficientes de Pearson e
# Spearman, mostrando os respectivos scatterplots com os valores dos coeficientes (como
# feito no exemplo).**

# %% [markdown]
# Veremos como se comporta o coeficiente de correlação de Pearson de acordo com diferentes tendências entre as variáveis $X$ e $Y$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

N = 100
X = np.linspace(-1,1, N)
erro = np.random.uniform(-0.5,0.5,N) # ruído a ser incluído na relação linear.
for sigma in np.arange(0,2,0.2):
  Y = 0.5*X + erro*sigma
  plt.plot(X,Y, 'ro')
  corr, p_value = pearsonr(X, Y) # calcula a correlação
  corr = int(corr*100)/100
  string = 'corr = '+ str(corr)
  plt.xlim(-1.5,1.5)
  plt.ylim(-2, 2)
  plt.text(0.6,1.7, string, fontsize=15)
  plt.show(True)

# %% [markdown]
# Calculando o coeficiente de Pearson

# %%
from scipy.stats import pearsonr, spearmanr

# Uma função para calcular a variância
def std(x):
  n = len(x)
  xm = 0
  for i in range(0,n):
    xm = xm + x[i]
  xm = xm/n
  std = 0
  for i in range(0,n):
    std = std + (x[i]-xm)**2
  std = np.sqrt(std/(n))
  return std

# Função para calcular o coeficiente de Pearson
def Pearson(x,y):
  n = len(x)
  # averages
  xm = 0
  ym = 0
  for i in range(0,n):
    xm = xm + x[i]
    ym = ym + y[i]
  xm = xm/n
  ym = ym/n
  r = 0
  for i in range(0,n):
    r = r + (x[i]-xm)*(y[i]-ym)
  r = r/n
  r = r/(std(x)*std(y))
  return r

print("Valor da correlação de Person calculado pela função:", Pearson(X,Y))
print("Valor da correlação de Person calculado usando o pacote statistics:", pearsonr(X, Y)[0])
# Out:
# Valor da correlação de Person calculado pela função: 0.6502738801267854
#
# Valor da correlação de Person calculado usando o pacote statistics: 0.6502738801267854

# %% [markdown]
# Gráfico Scatterplot - Correlação de Pearson

# %%
# Scatterplot
N = 100
X = np.linspace(-1,1, N) # gera N valores em [-1,1]
erro = np.random.uniform(-0.5,0.5,N) # ruído a ser incluído na relação linear.
sigma= 0.5
Y = 0.5*X + erro*sigma

fig= plt.figure(figsize=(6,4))

plt.scatter(X, Y, marker='o', color = 'black');
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("X",fontsize = 15) 
plt.ylabel("Y", fontsize = 15) 
plt.show(True)

# %% [markdown]
# Calculando o coeficiente de Spearman

# %%
xr = [sorted(X).index(i)+1 for i in X]
yr = [sorted(Y).index(i)+1 for i in Y] 
print("\nValor da correlação de Spearman calculado pela função:", Pearson(xr,yr))
print("Valor da correlação de Spearman calculado usando o pacote statistics:", spearmanr(xr, yr)[0])
# Out:
# Valor da correlação de Spearman calculado pela função: 0.2268106810681068
#
# Valor da correlação de Spearman calculado usando o pacote statistics: 0.22681068106810678

# %% [markdown]
# Gráfico scatterplot - Correlação de Spearman

# %%
# Scatterplot
N = 100
X = np.linspace(-1,1, N) # gera N valores em [-1,1]
erro = np.random.uniform(-0.5,0.5,N) # ruído a ser incluído na relação linear.
sigma= 0.5
Y = 0.5*X + erro*sigma

fig= plt.figure(figsize=(6,4))

plt.scatter(X, Y, marker='o', color = 'black');
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("X",fontsize = 15) 
plt.ylabel("Y", fontsize = 15) 
plt.show(True)

# %% [markdown]
# **6- Considere os dados abaixo, chamado quarteto de Ascomb. Calcule a média, variância,
# correlação de Pearson e Spearman entre as variáveis x e y. O que você pode dizer sobre
# esses dados?**

# %%
import matplotlib.pyplot as plt
import numpy as np
x1 = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]

datasets = {
 'I': (x1, y1),
 'II': (x1, y2),
 'III': (x1, y3),
 'IV': (x4, y4)
}

fig, axs = plt.subplots(2, 2, sharex=True, sharey=True, figsize=(10
, 5),
 gridspec_kw={'wspace': 0.08, 'hspace': 0.08
})
for ax, (label, (x, y)) in zip(axs.flat, datasets.items()):
 ax.text(0.1, 0.9, label, fontsize=20, transform=ax.transAxes, va='top')
 ax.tick_params(direction='in', top=True, right=True)
 ax.plot(x, y, 'o')
plt.show()

# %% [markdown]
# Funções e pacotes a serem utilizados:

# %%
from scipy.stats import pearsonr, spearmanr
import numpy as np 


# Variância 
def variancia(X):
    m = np.mean(X)
    N = len(X)
    s = 0
    for i in np.arange(0, len(X)):
        s = s + (X[i]-m)**2
    s = s/(N-1)
    return s


# Variância para o cálculo do coeficiente de Pearson
def std(x):
    n = len(x)
    xm = 0
    for i in range(0,n):
        xm = xm + x[i]
    xm = xm/n
    std = 0
    for i in range(0,n):
        std = std + (x[i]-xm)**2
    std = np.sqrt(std/(n))
    return std


# Coeficiente de Pearson
def Pearson(x,y):
    n = len(x)
    # averages
    xm = 0
    ym = 0
    for i in range(0,n):
        xm = xm + x[i]
        ym = ym + y[i]
    xm = xm/n
    ym = ym/n
    r = 0
    for i in range(0,n):
        r = r + (x[i]-xm)*(y[i]-ym)
    r = r/n
    r = r/(std(x)*std(y))
    return r

# %% [markdown]
# Calculando medidas de 'I': (x1, y1)

# %%
# Média
print('Média dos valores em x1:', np.mean(x1))
print('Média dos valores em y1:', np.mean(y1))

# Variância
print('\nVariância dos valores em x1:', variancia(x1))
print('Variância dos valores em y1:', variancia(y1))

# Coeficiente de Pearson
print('\nCoeficiente de Pearson:', Pearson(x1,y1))
print("Coeficiente de Pearson com o pacote statistics:", pearsonr(x1, y1)[0])

# Coeficiente de Spearman
x1r = [sorted(x1).index(i)+1 for i in x1]
y1r = [sorted(y1).index(i)+1 for i in y1] 
print("\nCoeficiente de Spearman:", Pearson(x1r,y1r))
print("Coeficiente de Spearman com o pacote statistics:", spearmanr(x1r, y1r)[0])
# Out:
# Média dos valores em x1: 9.0
#
# Média dos valores em y1: 7.500909090909093
#
#
#
# Variância dos valores em x1: 11.0
#
# Variância dos valores em y1: 4.127269090909091
#
#
#
# Coeficiente de Pearson: 0.8164205163448399
#
# Coeficiente de Pearson com o pacote statistics: 0.81642051634484
#
#
#
# Coeficiente de Spearman: 0.818181818181818
#
# Coeficiente de Spearman com o pacote statistics: 0.8181818181818182

# %% [markdown]
# Calculando medidas de 'I': (x1, y2)

# %%
# Média
print('Média dos valores em x1:', np.mean(x1))
print('Média dos valores em y2:', np.mean(y2))

# Variância
print('\nVariância dos valores em x1:', variancia(x1))
print('Variância dos valores em y2:', variancia(y2))

# Coeficiente de Pearson
print('\nCoeficiente de Pearson:', Pearson(x1,y2))
print("Coeficiente de Pearson com o pacote statistics:", pearsonr(x1, y2)[0])

# Coeficiente de Spearman
x1r = [sorted(x1).index(i)+1 for i in x1]
y2r = [sorted(y2).index(i)+1 for i in y2] 
print("\nCoeficiente de Spearman:", Pearson(x1r,y2r))
print("Coeficiente de Spearman com o pacote statistics:", spearmanr(x1r, y2r)[0])
# Out:
# Média dos valores em x1: 9.0
#
# Média dos valores em y2: 7.50090909090909
#
#
#
# Variância dos valores em x1: 11.0
#
# Variância dos valores em y2: 4.127629090909092
#
#
#
# Coeficiente de Pearson: 0.8162365060002427
#
# Coeficiente de Pearson com o pacote statistics: 0.8162365060002427
#
#
#
# Coeficiente de Spearman: 0.6909090909090908
#
# Coeficiente de Spearman com o pacote statistics: 0.690909090909091

# %% [markdown]
# Calculando medidas de 'I': (x1, y3)

# %%
# Média
print('Média dos valores em x1:', np.mean(x1))
print('Média dos valores em y3:', np.mean(y3))

# Variância
print('\nVariância dos valores em x1:', variancia(x1))
print('Variância dos valores em y3:', variancia(y3))

# Coeficiente de Pearson
print('\nCoeficiente de Pearson:', Pearson(x1,y3))
print("Coeficiente de Pearson com o pacote statistics:", pearsonr(x1, y3)[0])

# Coeficiente de Spearman
x1r = [sorted(x1).index(i)+1 for i in x1]
y3r = [sorted(y3).index(i)+1 for i in y3] 
print("\nCoeficiente de Spearman:", Pearson(x1r,y3r))
print("Coeficiente de Spearman com o pacote statistics:", spearmanr(x1r, y3r)[0])
# Out:
# Média dos valores em x1: 9.0
#
# Média dos valores em y3: 7.5
#
#
#
# Variância dos valores em x1: 11.0
#
# Variância dos valores em y3: 4.12262
#
#
#
# Coeficiente de Pearson: 0.8162867394895982
#
# Coeficiente de Pearson com o pacote statistics: 0.8162867394895982
#
#
#
# Coeficiente de Spearman: 0.9909090909090906
#
# Coeficiente de Spearman com o pacote statistics: 0.990909090909091

# %% [markdown]
# Calculando medidas de 'I': (x4, y4)

# %%
# Média
print('Média dos valores em x4:', np.mean(x4))
print('Média dos valores em y4:', np.mean(y4))

# Variância
print('\nVariância dos valores em x4:', variancia(x4))
print('Variância dos valores em y4:', variancia(y4))

# Coeficiente de Pearson
print('\nCoeficiente de Pearson:', Pearson(x4,y4))
print("Coeficiente de Pearson com o pacote statistics:", pearsonr(x4, y4)[0])

# Coeficiente de Spearman
x4r = [sorted(x4).index(i)+1 for i in x4]
y4r = [sorted(y4).index(i)+1 for i in y4] 
print("\nCoeficiente de Spearman:", Pearson(x4r,y4r))
print("Coeficiente de Spearman com o pacote statistics:", spearmanr(x4r, y4r)[0])
# Out:
# Média dos valores em x4: 9.0
#
# Média dos valores em y4: 7.500909090909091
#
#
#
# Variância dos valores em x4: 11.0
#
# Variância dos valores em y4: 4.123249090909091
#
#
#
# Coeficiente de Pearson: 0.8165214368885028
#
# Coeficiente de Pearson com o pacote statistics: 0.8165214368885029
#
#
#
# Coeficiente de Spearman: 0.5
#
# Coeficiente de Spearman com o pacote statistics: 0.5

# %% [markdown]
# Em todos os grupos, a média da variável x é 9 e a variância é 11; a média da variável y é 7.5 e a variância é 4.12 . O coeficiente de Pearson foi igual nos quatro conjuntos, tendo 0.816 como valor, e o de Spearman acabou variando. Percebe-se que, apesar dos conjuntos de dados serem semelhantes e possuírem estatísticas em comum, suas distribuições e aparências são muito distintas, sendo perceptível ao olhar os gráficos. O gráfico I apresenta uma  relação linear simples; o gráfico II mostra a existência de uma relação entre as variáveis, mas que não é linear e o coeficiente de correlação de Pearson não é relevante; o gráfico III a distribuição é linear, mas com uma reta de regressão diferente e o gráfico IV mostra que os pontos de dados não indicam qualquer relação entre as variáveis.
